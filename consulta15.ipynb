# %%
#crear una función lambda que sume 3 a cada numero de una lista
def suma_tres(numeros):
    resultado = list(map(lambda x: x + 3, numeros))
    return resultado
numeros = [1, 2, 3, 5, 8]
print(suma_tres(numeros))
# Out:
# [4, 5, 6, 8, 11]
